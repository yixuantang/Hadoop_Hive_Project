# %%
import re
import os
import sys
import numpy as np
import pandas as pd

# %%
print sys.version
# Out:
# 2.7.14 |Anaconda, Inc.| (default, Mar 27 2018, 17:29:31)
# [GCC 7.2.0]

# %%
#this txt contains all data links from 2010 to 2017
with open('MTA_links10-17.txt', 'r') as f:
    files = filter(len, map(lambda s: s.strip(), f.read().decode('utf-16').split('\n')))
files
# Out:
# [u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_171104.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_171028.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_171021.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_171014.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_171007.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170930.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170923.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170916.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170909.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170902.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170826.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170819.txt',
# ...

# %%
#select 2016 data
pattern16 = re.compile('.*/turnstile_16.*')
file16 = filter(pattern16.match, files)
file16
# Out:
# [u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_161231.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_161224.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_161217.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_161210.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_161203.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_161126.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_161119.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_161112.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_161105.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_161029.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_161022.txt',
#  u'http://web.mta.info/developers/data/nyct/turnstile/turnstile_161015.txt',
# ...

# %%
if not os.path.isfile('mta_2016_data.csv'):
    dfs = [
        pd.read_csv(f)
        for f in file16
    ]
    df = pd.concat(dfs)
    df.to_csv('mta_data.csv')
else:
    df = pd.read_csv('mta_2016_data.csv')
print(map(len,dfs))
print(len(df))
df.head()
# Out:
# [192348, 192067, 196631, 192025, 192045, 192257, 192495, 194409, 191622, 192515, 191831, 192301, 192901, 193732, 192678, 192878, 194878, 193139, 191612, 190540, 193222, 193387, 191494, 193335, 193871, 193064, 194030, 194492, 194055, 194379, 193090, 195729, 193397, 194346, 194466, 193366, 194292, 193284, 194516, 194154, 192946, 191890, 196533, 194776, 198884, 200834, 193982, 195366, 193748, 197666, 193164, 195361, 191787]
# 10267810
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/24/2016  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/24/2016  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/24/2016  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/24/2016  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/24/2016  19:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  5980509
# 1  REGULAR  5980531
# 2  REGULAR  5980613
# 3  REGULAR  5980899
# ...

# %%
print os.path.getsize('mta_data.csv')
# Out:
# 899686822

# %%
#get file size
def convert_bytes(num):
    """
    this function will convert bytes to MB.... GB... etc
    """
    for x in ['bytes', 'KB', 'MB', 'GB', 'TB']:
        if num < 1024.0:
            return "%3.1f %s" % (num, x)
        num /= 1024.0


def file_size(file_path):
    """
    this function will return the file size
    """
    if os.path.isfile(file_path):
        file_info = os.stat(file_path)
        return convert_bytes(file_info.st_size)


# Lets check the file size of MS Paint exe 
# or you can use any file path
file_path = 'mta_data.csv'
print file_size(file_path)
# Out:
# 858.0 MB
